# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('../../spinqnm/papers/intro_paper/MATPLOTLIB_RCPARAMS.sty')

# %%
data = np.genfromtxt("../data/benchmarking_gw150914.dat", dtype=None, names=True)
data['time']-data['time'][0]
# Out:
# array([     0,  13635,  54727,  97040, 148638, 155511, 177119, 198812,
#        220428, 242052, 263596, 285304, 306885, 328502, 350120, 371745,
#        393319, 414931])

# %%
plt.figure()
plt.plot((data['time']-data['time'][0])/ 60. / 60., data['lc1'], marker='o')
plt.plot((data['time']-data['time'][0])/ 60./ 60., data['lc2'], marker='o')
plt.xlabel("time (hours)")
plt.ylabel("samples accumulated")
plt.show()

# %%
from scipy.optimize import curve_fit

def f(x, A, B): # this is your 'straight line' y=f(x)
    return A*x + B

popt, pcov = curve_fit(f, x, y) # your data x, y to fit
